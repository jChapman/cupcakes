# %% [markdown]
# **Assumptions**
#
# * The last line refers to sales for the current day
#
#
# **Future improvements**
#
# * Allow user to select date which corrisponds to the last entry in the text files
# * Make graphs
# * Make week text less bad
# * Order output
# * Allow user to upload files
# * Make it more than a stupid jupyter notebook

# %%
import os
import datetime
from dataclasses import dataclass
import calendar
import itertools

# %%
@dataclass
class Revenue:
    total: int = 0
    basic_total: int = 0
    deluxe_total: int = 0
    count: int = 0
        
@dataclass
class YearlyRev(Revenue):
    year: int = 0
        
    @classmethod
    def fromDate(cls, date):
        return YearlyRev(year=date.year)
    
    def __str__(self):
        return f'Yearly revenue for {self.year}. Total Revenue: ${self.total}'
    
@dataclass
class MonthlyRev(Revenue):
    year: int = 0
    month: int = 0
        
    @classmethod
    def fromDate(cls, date):
        return MonthlyRev(year=date.year, month=date.month)
    
    def __str__(self):
        return f'Montly revenue for {calendar.month_name[self.month]} {self.year}. Total Revenue: ${self.total}'
    
@dataclass
class WeeklyRev(Revenue):
    year: int = 0
    month: int = 0
    week: int = 0

        
    @classmethod
    def fromDate(cls, date):
        return WeeklyRev(year=date.year, month=date.month, week=date.isocalendar()[:2])
    
    def __str__(self):
        return f'Weekly revenue for week {self.week}. Total Revenue: ${self.total}'

# %%
def read_values(filename):
    lines = []
    with open(filename) as f:
        for line in f:
            lines.append(line)
    return lines

# %%
basic_numbers = [int(x) for x in (read_values('Basic.txt')[1:])]
delux_numbers = [int(x) for x in (read_values('Delux.txt')[1:])]
total_numbers = [int(x) for x in (read_values('Total.txt')[1:])]

# %%
currDate = datetime.date.today()
dayDiff = datetime.timedelta(days=1)

currYearly = YearlyRev.fromDate(currDate)
currMonthly = MonthlyRev.fromDate(currDate)
currWeekly = WeeklyRev.fromDate(currDate)
yearlyRev = [currYearly]
monthlyRev = [currMonthly]
weeklyRev = [currWeekly]
for basic, delux, total in zip(basic_numbers[::-1], delux_numbers[::-1], total_numbers[::-1]):
    basic_value = basic * 5
    delux_value = delux * 6
    for rev in [currYearly, currMonthly, currWeekly]:
        rev.count += 1
        rev.total += total
        rev.basic_total += basic_value
        rev.deluxe_total += delux_value
    currDate = currDate - dayDiff
    # Determine if week/month/year has changed
    if currDate.isoweekday() == 5:
        currWeekly = WeeklyRev.fromDate(currDate)
        weeklyRev.append(currWeekly)
    if currDate.month != currMonthly.month:
        currMonthly = MonthlyRev.fromDate(currDate)
        monthlyRev.append(currMonthly)
    if currDate.year != currMonthly.year:
        currYearly = YearlyRev.fromDate(currDate)
        yearlyRev.append(currYearly)

# %%
# Required stats
for rev in itertools.chain(weeklyRev, monthlyRev, yearlyRev):
    print(rev)
# Out:
# Weekly revenue for week (2019, 43). Total Revenue: $214
# Weekly revenue for week (2019, 42). Total Revenue: $624
# Weekly revenue for week (2019, 41). Total Revenue: $821
# Weekly revenue for week (2019, 40). Total Revenue: $661
# Weekly revenue for week (2019, 39). Total Revenue: $593
# Weekly revenue for week (2019, 38). Total Revenue: $572
# Weekly revenue for week (2019, 37). Total Revenue: $555
# Weekly revenue for week (2017, 28). Total Revenue: $796
# Weekly revenue for week (2017, 27). Total Revenue: $500
# Weekly revenue for week (2017, 26). Total Revenue: $428
# Weekly revenue for week (2017, 25). Total Revenue: $405
# Weekly revenue for week (2017, 24). Total Revenue: $613
# Weekly revenue for week (2017, 23). Total Revenue: $518
# Weekly revenue for week (2017, 22). Total Revenue: $655
# Weekly revenue for week (2017, 21). Total Revenue: $688
# Weekly revenue for week (2017, 20). Total Revenue: $638
# Weekly revenue for week (2017, 19). Total Revenue: $683
# Weekly revenue for week (2017, 18). Total Revenue: $605
# Weekly revenue for week (2017, 17). Total Revenue: $764
# Weekly revenue for week (2017, 16). Total Revenue: $716
# Weekly revenue for week (2017, 15). Total Revenue: $674
# Weekly revenue for week (2017, 14). Total Revenue: $740
# Weekly revenue for week (2017, 13). Total Revenue: $654
# Weekly revenue for week (2017, 12). Total Revenue: $441
# Weekly revenue for week (2017, 11). Total Revenue: $706
# Weekly revenue for week (2017, 10). Total Revenue: $630
# Weekly revenue for week (2017, 9). Total Revenue: $681
# Weekly revenue for week (2017, 8). Total Revenue: $598
# Weekly revenue for week (2017, 7). Total Revenue: $698
# Weekly revenue for week (2017, 6). Total Revenue: $636
# Weekly revenue for week (2017, 5). Total Revenue: $522
# Weekly revenue for week (2017, 4). Total Revenue: $230
# Montly revenue for October 2019. Total Revenue: $1980
# Montly revenue for September 2019. Total Revenue: $2577
# Montly revenue for August 2019. Total Revenue: $2910
# Montly revenue for July 2019. Total Revenue: $2758
# Montly revenue for June 2019. Total Revenue: $2768
# Montly revenue for May 2019. Total Revenue: $2980
# Montly revenue for April 2019. Total Revenue: $2961
# Montly revenue for March 2019. Total Revenue: $2542
# Montly revenue for February 2019. Total Revenue: $2143
# Montly revenue for January 2019. Total Revenue: $2701
# Montly revenue for December 2018. Total Revenue: $2989
# Montly revenue for November 2018. Total Revenue: $2652
# Montly revenue for October 2018. Total Revenue: $2622
# Montly revenue for September 2018. Total Revenue: $3116
# Montly revenue for August 2018. Total Revenue: $2715
# Montly revenue for July 2018. Total Revenue: $2926
# Montly revenue for June 2018. Total Revenue: $2755
# Montly revenue for May 2018. Total Revenue: $2584
# Montly revenue for April 2018. Total Revenue: $3065
# Montly revenue for March 2018. Total Revenue: $2760
# Montly revenue for February 2018. Total Revenue: $2299
# Montly revenue for January 2018. Total Revenue: $2656
# Montly revenue for December 2017. Total Revenue: $2720
# Montly revenue for November 2017. Total Revenue: $2685
# Montly revenue for October 2017. Total Revenue: $2639
# Montly revenue for September 2017. Total Revenue: $2761
# Montly revenue for August 2017. Total Revenue: $2947
# Montly revenue for July 2017. Total Revenue: $2587
# Montly revenue for June 2017. Total Revenue: $2171
# Montly revenue for May 2017. Total Revenue: $2877
# Montly revenue for April 2017. Total Revenue: $3079
# Montly revenue for March 2017. Total Revenue: $2736
# Montly revenue for February 2017. Total Revenue: $2442
# Montly revenue for January 2017. Total Revenue: $618
# Yearly revenue for 2019. Total Revenue: $89721
